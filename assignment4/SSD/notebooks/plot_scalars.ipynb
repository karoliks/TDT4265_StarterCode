# %%
import sys, os
sys.path.append(os.path.dirname(os.getcwd())) # Include ../SSD in path
import tops
import matplotlib.pyplot as plt
import pathlib
from ssd.utils import load_config

# %%
cfg = load_config("../configs/ssd300.py")
logs = tops.logger.read_logs(pathlib.Path("../outputs/ssd300"))
# Out:
# It looks like you are currently working on the server, with a 'working directory' in: /work/snotra/karoliks
# Saving all SSD outputs to: /work/snotra/karoliks/ssd_outputs
# Found dataset directory in: /work/datasets/mnist_object_detection/train
# Found dataset directory in: /work/datasets/mnist_object_detection/val

# %%
# The log is formatted as a list of dictionaries
print(logs[:10])
# Out:
# [{'amp/grad_scale': 32768.0, 'global_step': 0}, {'loss/regression_loss': 2.896953821182251, 'loss/classification_loss': 9.695448875427246, 'loss/total_loss': 12.592402458190918, 'global_step': 0}, {'stats/learning_rate': 0.000509, 'global_step': 1}, {'stats/learning_rate': 0.000518, 'global_step': 2}, {'stats/learning_rate': 0.000527, 'global_step': 3}, {'stats/learning_rate': 0.000536, 'global_step': 4}, {'stats/learning_rate': 0.000545, 'global_step': 5}, {'stats/learning_rate': 0.000554, 'global_step': 6}, {'stats/learning_rate': 0.000563, 'global_step': 7}, {'stats/learning_rate': 0.0005719999999999999, 'global_step': 8}]

# %%
# We are saving logs to disk every 10th iteration, thus we need to filter out all entries without a loss
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]

# %%
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries])
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')

# %%
logs = tops.logger.read_logs(pathlib.Path("../outputs/tdt4265"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries])
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')

# %%
logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task22"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries])
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')

# %%
logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task22_2"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries])
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')

# %%
logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_1"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries])
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')

# %%
plt.ylim([0.0, 4.0])
logs = tops.logger.read_logs(pathlib.Path("../outputs/tdt4265"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="Baseline")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_1"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_2"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_3"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss + Deeper conv nets")


plt.legend()
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')

# %%
plt.ylim([0.0, 2.0])
logs = tops.logger.read_logs(pathlib.Path("../outputs/tdt4265"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="Baseline")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_1"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_2"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_3"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss + Deeper conv nets")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_4"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss + Deeper conv nets + Weight init")


plt.legend()
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')

# %%
plt.ylim([0.0, 0.5])
logs = tops.logger.read_logs(pathlib.Path("../outputs/tdt4265"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="Baseline")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_1"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_2"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_3"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss + Deeper conv nets")

logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_4"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss + Deeper conv nets + Weight init")


plt.legend()
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')

# %%
logs = tops.logger.read_logs(pathlib.Path("/work/snotra/karoliks/ssd_outputs/task23_4"))
loss_entries = [entry for entry in logs if "loss/regression_loss" in entry]
plt.plot([entry["global_step"] for entry in loss_entries], [entry["loss/regression_loss"] for entry in loss_entries], label="FPN + Focal Loss + Deeper conv nets")


plt.legend()
plt.ylabel("Regression loss")
plt.xlabel("Global step (number of batches trained on)")
# Out:
# Text(0.5, 0, 'Global step (number of batches trained on)')
